# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import truncnorm, norm
from scipy.optimize import fmin

# %% [markdown]
# ### Read data

# %%
# Data set from https://www.kaggle.com/datasets/tunguz/big-five-personality-test
df = pd.read_csv("data/BIG5/data.csv", delimiter="\t")
print(df.shape)
df.head()
# Out:
# (19719, 57)
#    race  age  engnat  gender  hand  source country  E1  E2  E3  ...  O1  O2  \
# 0     3   53       1       1     1       1      US   4   2   5  ...   4   1
# 1    13   46       1       2     1       1      US   2   2   3  ...   3   3
# 2     1   14       2       2     1       1      PK   5   1   1  ...   4   5
# 3     3   19       2       2     1       1      RO   2   5   2  ...   4   3
# 4    11   25       2       2     1       2      US   3   1   3  ...   3   1
#
#    O3  O4  O5  O6  O7  O8  O9  O10
# 0   3   1   5   1   4   2   5    5
# 1   3   3   2   3   3   1   3    2
# 2   5   1   5   1   5   5   5    5
# 3   5   2   4   2   5   2   5    5
# 4   1   1   3   1   3   1   5    3
#
# [5 rows x 57 columns]

# %% [markdown]
# ### Data pre-processing
#
# Some questions/statements, such as E2 ("I don't talk a lot") are "inverted" in the sense that a high score should contribute less to extraversion. We find these and invert the scores (1 -> 5, 2 -> 4...).

# %%
# First, drop columns except age, gender, and answers to the test questions
test_answers = [col for col in df.columns if col.isupper()]
cols_to_keep = test_answers + ['age', 'gender']
df_clean = df[cols_to_keep].copy()

# Only consider male (1) and female (2) genders
df_clean = df_clean[df_clean['gender'].isin([1, 2])]
df_clean['gender'] -= 1 # Male (0) and female(1)

inverse_score = {1:5, 2:4, 3:3, 4:2, 5:1}
inverse_questions = ['E2', 'E4', 'E6', 'E8', 'E10',
                    'N2', 'N4',
                    'A1', 'A3', 'A5', 'A7', 
                    'C2', 'C4', 'C6', 'C8', 
                    'O2', 'O4', 'O6']

# Invert scores for specified columns
df_clean[inverse_questions] = df_clean[inverse_questions].replace(inverse_score)

print(df_clean.shape)
df_clean.head()
# Out:
# (19593, 52)
#    E1  E2  E3  E4  E5  E6  E7  E8  E9  E10  ...  O3  O4  O5  O6  O7  O8  O9  \
# 0   4   4   5   4   5   5   4   3   5    5  ...   3   5   5   5   4   2   5
# 1   2   4   3   3   3   3   1   1   1    1  ...   3   3   2   3   3   1   3
# 2   5   5   1   2   5   5   1   1   5    5  ...   5   5   5   5   5   5   5
# 3   2   1   2   2   3   2   3   2   4    1  ...   5   4   4   4   5   2   5
# 4   3   5   3   3   3   5   3   5   3    1  ...   1   5   3   5   3   1   5
#
#    O10  age  gender
# 0    5   53       0
# 1    2   46       1
# 2    5   14       1
# 3    5   19       1
# 4    3   25       1
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Distributions
#
# First, we check the distribution of scores as histograms. The results for conscientiousness, extraversion and neuroticism look normally distributed, whereas the results for openness and agreeableness look skewed towards a higher score.

# %%
traits = {
    'Openness': [f'O{i}' for i in range(1, 11)],
    'Conscientiousness': [f'C{i}' for i in range(1, 11)],
    'Extraversion': [f'E{i}' for i in range(1, 11)],
    'Agreeableness': [f'A{i}' for i in range(1, 11)],
    'Neuroticism': [f'N{i}' for i in range(1, 11)]
}

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 9))
axes = axes.flatten()

for (trait, columns), ax in zip(traits.items(), axes):
    df_clean[trait] = df_clean[columns].sum(axis=1)
    mu = df_clean[trait].mean()
    sigma = df_clean[trait].std()
    
    ax.hist(df_clean[trait], bins=15, alpha=0.7)

    ax.set_title(f'{trait}')
    ax.set_xlabel('Score')
    ax.set_ylabel('Samples')
    ax.text(0.03, 0.95, f'Mean: {mu:.2f}\nStd: {sigma:.2f}', transform=ax.transAxes, verticalalignment='top')

axes[5].axis('off')

plt.tight_layout()
plt.show()

df_clean.head()
# Out:
#    E1  E2  E3  E4  E5  E6  E7  E8  E9  E10  ...  O8  O9  O10  age  gender  \
# 0   4   4   5   4   5   5   4   3   5    5  ...   2   5    5   53       0
# 1   2   4   3   3   3   3   1   1   1    1  ...   1   3    2   46       1
# 2   5   5   1   2   5   5   1   1   5    5  ...   5   5    5   14       1
# 3   2   1   2   2   3   2   3   2   4    1  ...   2   5    5   19       1
# 4   3   5   3   3   3   5   3   5   3    1  ...   1   5    3   25       1
#
#    Openness  Conscientiousness  Extraversion  Agreeableness  Neuroticism
# 0        43                 47            44             46           11
# 1        26                 42            22             35           31
# 2        45                 49            35             38           46
# 3        41                 26            22             37           43
# 4        34                 34            34             44           30
#
# [5 rows x 57 columns]

# %% [markdown]
# We want to fit truncated normal distributions in the range [10, 50].

# %%
# Define a loss function to optimize against
def neg_log_likelihood(params, data, lower_bound, upper_bound):
    mu, sigma = params
    if sigma <= 0:
        return np.inf
    loglik = np.sum(truncnorm.logpdf(data, (lower_bound-mu)/sigma, (upper_bound-mu)/sigma, loc=mu, scale=sigma))
    return -loglik

lower_bound, upper_bound = 10, 50

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 9))
axes = axes.flatten()

for trait, ax in zip(traits.keys(), axes):
    data = df_clean[trait].values
    # Initial parameter estimates
    mu_init, sigma_init = np.mean(data), np.std(data)
    params_init = [mu_init, sigma_init]

    # Find parameters that minimize the negative log-likelihood
    params_estimated = fmin(neg_log_likelihood, params_init, args=(data, lower_bound, upper_bound), disp=0)

    # Plot the histogram
    ax.hist(df_clean[trait], density=True, label='Data', bins=15, alpha=0.7)

    # Plot the estimated truncated normal distribution
    x = np.linspace(lower_bound, upper_bound, 1000)
    y = truncnorm.pdf(x, (lower_bound-params_estimated[0]) / params_estimated[1], \
            (upper_bound - params_estimated[0]) / params_estimated[1], loc=params_estimated[0], scale=params_estimated[1])
    ax.plot(x, y, 'r-', label='Truncated Normal Fit')
    
    ax.set_xlabel('Score')
    ax.set_ylabel('Density')
    ax.set_title(f'Distribution for {trait}')
    ax.legend()

axes[5].axis('off')

plt.tight_layout()
plt.show()
# Out:
# /home/adrimur/.local/lib/python3.8/site-packages/scipy/optimize/_optimize.py:863: RuntimeWarning: invalid value encountered in subtract
#   np.max(np.abs(fsim[0] - fsim[1:])) <= fatol):

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

labels = df_clean['gender']
features = df_clean[test_answers + ['age']]

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1664
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 2209 (8.63 KB)
# Trainable params: 2209 (8.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# /home/adrimur/.local/lib/python3.8/site-packages/keras/src/engine/data_adapter.py:1798: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 392/392 [==============================] - 1s 1ms/step - loss: 0.6861 - accuracy: 0.6249 - val_loss: 0.6571 - val_accuracy: 0.6523
# Epoch 2/50
# 392/392 [==============================] - 0s 940us/step - loss: 0.6323 - accuracy: 0.6603 - val_loss: 0.6184 - val_accuracy: 0.6683
# Epoch 3/50
# 392/392 [==============================] - 0s 914us/step - loss: 0.6391 - accuracy: 0.6719 - val_loss: 0.6908 - val_accuracy: 0.6718
# Epoch 4/50
# 392/392 [==============================] - 0s 876us/step - loss: 0.6378 - accuracy: 0.6713 - val_loss: 0.6426 - val_accuracy: 0.6683
# Epoch 5/50
# 392/392 [==============================] - 0s 930us/step - loss: 0.6096 - accuracy: 0.6775 - val_loss: 0.6068 - val_accuracy: 0.6727
# Epoch 6/50
# 392/392 [==============================] - 0s 900us/step - loss: 0.6044 - accuracy: 0.6802 - val_loss: 0.5973 - val_accuracy: 0.6785
# Epoch 7/50
# 392/392 [==============================] - 0s 874us/step - loss: 0.6033 - accuracy: 0.6800 - val_loss: 0.6020 - val_accuracy: 0.6756
# Epoch 8/50
# 392/392 [==============================] - 0s 1ms/step - loss: 0.6045 - accuracy: 0.6814 - val_loss: 0.5915 - val_accuracy: 0.6810
# Epoch 9/50
# 392/392 [==============================] - 0s 999us/step - loss: 0.6073 - accuracy: 0.6818 - val_loss: 0.6150 - val_accuracy: 0.6772
# Epoch 10/50
# 392/392 [==============================] - 0s 918us/step - loss: 0.5955 - accuracy: 0.6863 - val_loss: 0.5954 - val_accuracy: 0.6845
# Epoch 11/50
# 392/392 [==============================] - 0s 951us/step - loss: 0.5982 - accuracy: 0.6864 - val_loss: 0.5931 - val_accuracy: 0.6842
# Epoch 12/50
# 392/392 [==============================] - 0s 899us/step - loss: 0.5938 - accuracy: 0.6860 - val_loss: 0.5953 - val_accuracy: 0.6852
# Epoch 13/50
# 392/392 [==============================] - 0s 875us/step - loss: 0.5954 - accuracy: 0.6889 - val_loss: 0.5956 - val_accuracy: 0.6791
# Epoch 14/50
# 392/392 [==============================] - 0s 892us/step - loss: 0.5922 - accuracy: 0.6867 - val_loss: 0.6160 - val_accuracy: 0.6813
# Epoch 15/50
# 392/392 [==============================] - 0s 871us/step - loss: 0.5951 - accuracy: 0.6886 - val_loss: 0.5850 - val_accuracy: 0.6871
# Epoch 16/50
# 392/392 [==============================] - 0s 875us/step - loss: 0.5867 - accuracy: 0.6889 - val_loss: 0.5882 - val_accuracy: 0.6804
# Epoch 17/50
# 392/392 [==============================] - 0s 872us/step - loss: 0.5878 - accuracy: 0.6898 - val_loss: 0.5989 - val_accuracy: 0.6810
# Epoch 18/50
# 392/392 [==============================] - 0s 863us/step - loss: 0.5862 - accuracy: 0.6934 - val_loss: 0.5963 - val_accuracy: 0.6750
# Epoch 19/50
# 392/392 [==============================] - 0s 873us/step - loss: 0.5871 - accuracy: 0.6902 - val_loss: 0.5987 - val_accuracy: 0.6823
# Epoch 20/50
# 392/392 [==============================] - 0s 905us/step - loss: 0.5871 - accuracy: 0.6914 - val_loss: 0.5897 - val_accuracy: 0.6823
# Epoch 21/50
# 392/392 [==============================] - 0s 875us/step - loss: 0.5842 - accuracy: 0.6927 - val_loss: 0.5932 - val_accuracy: 0.6801
# Epoch 22/50
# 392/392 [==============================] - 0s 872us/step - loss: 0.5830 - accuracy: 0.6907 - val_loss: 0.6067 - val_accuracy: 0.6813
# Epoch 23/50
# 392/392 [==============================] - 0s 877us/step - loss: 0.5798 - accuracy: 0.6930 - val_loss: 0.5898 - val_accuracy: 0.6766
# Epoch 24/50
# 392/392 [==============================] - 0s 872us/step - loss: 0.5779 - accuracy: 0.6961 - val_loss: 0.5903 - val_accuracy: 0.6801
# Epoch 25/50
# 392/392 [==============================] - 0s 875us/step - loss: 0.5822 - accuracy: 0.6935 - val_loss: 0.5905 - val_accuracy: 0.6861
# Epoch 26/50
# 392/392 [==============================] - 0s 893us/step - loss: 0.5818 - accuracy: 0.6952 - val_loss: 0.6030 - val_accuracy: 0.6858
# Epoch 27/50
# 392/392 [==============================] - 0s 882us/step - loss: 0.5795 - accuracy: 0.6978 - val_loss: 0.5929 - val_accuracy: 0.6804
# Epoch 28/50
# 392/392 [==============================] - 0s 869us/step - loss: 0.5771 - accuracy: 0.6977 - val_loss: 0.5874 - val_accuracy: 0.6842
# Epoch 29/50
# 392/392 [==============================] - 0s 883us/step - loss: 0.5765 - accuracy: 0.6966 - val_loss: 0.5839 - val_accuracy: 0.6823
# Epoch 30/50
# 392/392 [==============================] - 0s 884us/step - loss: 0.5772 - accuracy: 0.6960 - val_loss: 0.5869 - val_accuracy: 0.6797
# Epoch 31/50
# 392/392 [==============================] - 0s 905us/step - loss: 0.5738 - accuracy: 0.6984 - val_loss: 0.5829 - val_accuracy: 0.6874
# Epoch 32/50
# 392/392 [==============================] - 0s 883us/step - loss: 0.5716 - accuracy: 0.6984 - val_loss: 0.5853 - val_accuracy: 0.6801
# Epoch 33/50
# 392/392 [==============================] - 0s 901us/step - loss: 0.5718 - accuracy: 0.7005 - val_loss: 0.5948 - val_accuracy: 0.6807
# Epoch 34/50
# 392/392 [==============================] - 0s 875us/step - loss: 0.5739 - accuracy: 0.6985 - val_loss: 0.5844 - val_accuracy: 0.6791
# Epoch 35/50
# 392/392 [==============================] - 0s 899us/step - loss: 0.5700 - accuracy: 0.7029 - val_loss: 0.5841 - val_accuracy: 0.6772
# Epoch 36/50
# 392/392 [==============================] - 0s 894us/step - loss: 0.5711 - accuracy: 0.7005 - val_loss: 0.5841 - val_accuracy: 0.6839
# Epoch 37/50
# 392/392 [==============================] - 0s 889us/step - loss: 0.5683 - accuracy: 0.7043 - val_loss: 0.5954 - val_accuracy: 0.6858
# Epoch 38/50
# 392/392 [==============================] - 0s 869us/step - loss: 0.5699 - accuracy: 0.7016 - val_loss: 0.6020 - val_accuracy: 0.6766
# Epoch 39/50
# 392/392 [==============================] - 0s 891us/step - loss: 0.5678 - accuracy: 0.7023 - val_loss: 0.5858 - val_accuracy: 0.6900
# Epoch 40/50
# 392/392 [==============================] - 0s 881us/step - loss: 0.5648 - accuracy: 0.7033 - val_loss: 0.5878 - val_accuracy: 0.6839
# Epoch 41/50
# 392/392 [==============================] - 0s 904us/step - loss: 0.5666 - accuracy: 0.7008 - val_loss: 0.5902 - val_accuracy: 0.6750
# Epoch 42/50
# 392/392 [==============================] - 0s 882us/step - loss: 0.5614 - accuracy: 0.7079 - val_loss: 0.5924 - val_accuracy: 0.6801
# Epoch 43/50
# 392/392 [==============================] - 0s 922us/step - loss: 0.5621 - accuracy: 0.7033 - val_loss: 0.6010 - val_accuracy: 0.6769
# Epoch 44/50
# 392/392 [==============================] - 0s 893us/step - loss: 0.5661 - accuracy: 0.7048 - val_loss: 0.5869 - val_accuracy: 0.6801
# Epoch 45/50
# 392/392 [==============================] - 0s 873us/step - loss: 0.5612 - accuracy: 0.7067 - val_loss: 0.5865 - val_accuracy: 0.6813
# Epoch 46/50
# 392/392 [==============================] - 0s 879us/step - loss: 0.5620 - accuracy: 0.7064 - val_loss: 0.5958 - val_accuracy: 0.6868
# Epoch 47/50
# 392/392 [==============================] - 0s 881us/step - loss: 0.5638 - accuracy: 0.7048 - val_loss: 0.5852 - val_accuracy: 0.6912
# Epoch 48/50
# 392/392 [==============================] - 0s 942us/step - loss: 0.5615 - accuracy: 0.7055 - val_loss: 0.5897 - val_accuracy: 0.6826
# Epoch 49/50
# 392/392 [==============================] - 0s 1ms/step - loss: 0.5595 - accuracy: 0.7109 - val_loss: 0.5934 - val_accuracy: 0.6874
# Epoch 50/50
# 392/392 [==============================] - 0s 1ms/step - loss: 0.5567 - accuracy: 0.7110 - val_loss: 0.5855 - val_accuracy: 0.6801

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)  # Class labels

precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# 123/123 [==============================] - 0s 549us/step
# Precision: 0.7014
# Recall: 0.8364
# F1 Score: 0.7629
